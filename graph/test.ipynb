# %%
from graph import Graph

# %%
G0 = Graph()
G0.add_edge(u='1', v='2')
G0.add_vertex(v='3')

# %%
G1 = Graph([1,2,3], [(1,2)])

# %%
print(f"Vertices: {G0.vertices}")
print(f"Edges   : {G0.edges}")
# Out:
# Vertices: ['1', '2', 3]
# Edges   : [('1', '2')]

# %%
print(f"Vertices: {G1.vertices}")
print(f"Edges   : {G1.edges}")
# Out:
# Vertices: [1, 2, 3]
# Edges   : [(1, 2)]

# %%
G0
# Out:
# Graph with 3 vertices and 1 edges

# %%
G1
# Out:
# Graph with 3 vertices and 1 edges

# %%
print(G0)
print(G1)
# Out:
# Graph with vertices ['1', '2', 3] and edges [('1', '2')]
# Graph with vertices [1, 2, 3] and edges [(1, 2)]

# %%
G0.draw()

# %%
G1.draw()

# %%
G0.draw('neato')

# %%
G2=Graph()
G2.add_weighted_edge(1,2,50)
G2.add_weighted_edge(2,3,-5)
G2.add_weighted_edge(3,1,0)
G2.draw_weighted('circo')

# %%
G2=Graph([], [(1,2), (2,3), (3,1)])
G2.weighted([50,-5, 0])
G2.draw_weighted('circo')

# %%
G2.dict_weights
# Out:
# {(1, 2): 50, (2, 3): -5, (3, 1): 0}

# %%
G2.highlight_node(3)
